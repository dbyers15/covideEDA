# %%
import pandas as pd

# %%
orginalDF = pd.read_csv('Conditions_Contributing_to_COVID-19_Deaths__by_State_and_Age.csv')

# %%
orginalDF
# Out:
#         Data As Of  Start Date    End Date     Group    Year  Month  \
# 0       07/25/2021  01/01/2020  07/24/2021  By Total     NaN    NaN
# 1       07/25/2021  01/01/2020  07/24/2021  By Total     NaN    NaN
# 2       07/25/2021  01/01/2020  07/24/2021  By Total     NaN    NaN
# 3       07/25/2021  01/01/2020  07/24/2021  By Total     NaN    NaN
# 4       07/25/2021  01/01/2020  07/24/2021  By Total     NaN    NaN
# ...            ...         ...         ...       ...     ...    ...
# 273235  07/25/2021  03/01/2021  03/31/2021  By Month  2021.0    3.0
# 273236  07/25/2021  04/01/2021  04/30/2021  By Month  2021.0    4.0
# 273237  07/25/2021  05/01/2021  05/31/2021  By Month  2021.0    5.0
# 273238  07/25/2021  06/01/2021  06/30/2021  By Month  2021.0    6.0
# 273239  07/25/2021  07/01/2021  07/24/2021  By Month  2021.0    7.0
#
#                 State       Condition Group                Condition  \
# 0       United States  Respiratory diseases  Influenza and pneumonia
# ...

# %%
afterDrop = orginalDF.drop(["ICD10_codes","Flag","Number of Mentions","Data As Of"], axis = 1)

# %%
afterDrop
# Out:
#         Start Date    End Date     Group    Year  Month          State  \
# 0       01/01/2020  07/24/2021  By Total     NaN    NaN  United States
# 1       01/01/2020  07/24/2021  By Total     NaN    NaN  United States
# 2       01/01/2020  07/24/2021  By Total     NaN    NaN  United States
# 3       01/01/2020  07/24/2021  By Total     NaN    NaN  United States
# 4       01/01/2020  07/24/2021  By Total     NaN    NaN  United States
# ...            ...         ...       ...     ...    ...            ...
# 273235  03/01/2021  03/31/2021  By Month  2021.0    3.0    Puerto Rico
# 273236  04/01/2021  04/30/2021  By Month  2021.0    4.0    Puerto Rico
# 273237  05/01/2021  05/31/2021  By Month  2021.0    5.0    Puerto Rico
# 273238  06/01/2021  06/30/2021  By Month  2021.0    6.0    Puerto Rico
# 273239  07/01/2021  07/24/2021  By Month  2021.0    7.0    Puerto Rico
#
#              Condition Group                Condition Age Group  \
# ...

# %% [markdown]
# **Assumptions**
#
# The decriptions for how the data has been recorded make close to no sense. There are also errors in the inputting of the data that must be cleaned. I have so far removed columns that provide no benefical information for what I am trying to do

# %% [markdown]
# Create tables that only contain by total, by month, etc.
